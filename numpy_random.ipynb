# %%
import matplotlib.pyplot as plt
from numpy import random
x = random.randint(100,size =(5,2))
print(x)
y = random.rand(2,3)
print(y)
z = random.choice([2,4,5,6],size = (2,3))
z
# Out:
# [[15 15]
#  [41 12]
#  [95 32]
#  [40 43]
#  [27 27]]
# [[0.49891815 0.8172098  0.69263132]
#  [0.25127843 0.11788216 0.21958804]]
# array([[4, 4, 5],
#        [4, 4, 5]])

# %%
proba_distr = random.choice([3,4,5,6],p=[0.2,0.4,0.1,0.3],size = 10)
proba_distr
# Out:
# array([5, 3, 6, 6, 5, 3, 3, 6, 3, 4])

# %%
import numpy as np
arr1 = np.array([1,2,3,4,5,6])
random.shuffle(arr1)
print(arr1)
arr2 = random.permutation(arr1)
print(arr1)
arr2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import numpy as np
#       2 arr1 = np.array([1,2,3,4,5,6])
# ----> 3 random.shuffle(arr1)
#       4 print(arr1)
#       5 arr2 = random.permutation(arr1)
#
# NameError: name 'random' is not defined

# %%
import seaborn as sns
sns.distplot([0,1,2,3,4,5],hist=False)
# Out:
# C:\Users\Hiwot\AppData\Local\Temp\ipykernel_13416\4048894636.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5],hist=False)
# C:\Users\Hiwot\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
sns.distplot(random.normal(loc = 10,scale =3,size=(2,3)),hist = False)
# Out:
# C:\Users\Hiwot\AppData\Local\Temp\ipykernel_9976\492744418.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc = 10,scale =3,size=(2,3)),hist = False,kde = True)
# C:\Users\Hiwot\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
sns.distplot(random.binomial(n = 10,p=0.5,size = 1000),hist = True,kde = False)
# Out:
# C:\Users\Hiwot\AppData\Local\Temp\ipykernel_9976\1212375633.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n = 10,p=0.5,size = 1000),hist = True,kde = False)
# <Axes: >

# %%
sns.distplot(np.random.uniform(size=100),hist =False)
# Out:
# C:\Users\Hiwot\AppData\Local\Temp\ipykernel_13416\154573889.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.uniform(size=100),hist =False)
# C:\Users\Hiwot\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
sns.displot(np.random.poisson(lam = 2,size = 100))
# Out:
# C:\Users\Hiwot\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Hiwot\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(random.logistic(loc = 1, scale = 2, size =1000))
plt.show()
# Out:
# C:\Users\Hiwot\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Hiwot\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.distplot(random.exponential(scale = 2, size=1000),hist = False)
# Out:
# C:\Users\Hiwot\AppData\Local\Temp\ipykernel_13416\3105792747.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.exponential(scale = 2, size=1000),hist = False)
# C:\Users\Hiwot\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
#numpy universal functions
x = [1,2,3]
y = [4,5,6]
z = np.add(x,y)
z
# Out:
# array([5, 7, 9])

# %%
def myadd(x,y):
    return x + y
my_add = np.frompyfunc(myadd,2,1)
w = my_add(x,y)
w
# Out:
# array([5, 7, 9], dtype=object)

# %%
def my_add(x,y):
    return x +y
myadd = np.frompyfunc(my_add,2,1) # to create my own universal function
x = [1,2,3]
y = [5,6,7]
z = myadd(x,y)
z
# Out:
# array([6, 8, 10], dtype=object)

# %%
#checkin universal functions
print(type(np.add))
# Out:
# <class 'numpy.ufunc'>

# %%
x = np.array([23,45,63,78,19,10,34,56])
y = np.array([34,45,56,45,63,23,11,12])
z = np.add(x,y)
z
# Out:
# array([ 57,  90, 119, 123,  82,  33,  45,  68])

# %%
z = np.subtract(x,y)
z
# Out:
# array([-11,   0,   7,  33, -44, -13,  23,  44])

# %%
z = np.multiply(x,y)
z
# Out:
# array([ 782, 2025, 3528, 3510, 1197,  230,  374,  672])

# %%
z = np.divide(x,y)
z
# Out:
# array([0.67647059, 1.        , 1.125     , 1.73333333, 0.3015873 ,
#        0.43478261, 3.09090909, 4.66666667])

# %%
z = np.divmod(x,y)
z
# Out:
# (array([0, 1, 1, 1, 0, 0, 3, 4]), array([23,  0,  7, 33, 19, 10,  1,  8]))

# %%
z = np.power(x,np.zeros(len(x)))
z
# Out:
# array([1., 1., 1., 1., 1., 1., 1., 1.])

# %%
z = np.remainder(x,y)
z
# Out:
# array([23,  0,  7, 33, 19, 10,  1,  8])

# %%
x = np.array([-1,-2,3,-5])
z = np.absolute(x)
z
# Out:
# array([1, 2, 3, 5])

# %%
x = np.arange(1,10)
print(np.log2(x))
# Out:
# [0.         1.         1.5849625  2.         2.32192809 2.5849625
#  2.80735492 3.         3.169925  ]

# %%
np.log10(x)
# Out:
# array([0.        , 0.30103   , 0.47712125, 0.60205999, 0.69897   ,
#        0.77815125, 0.84509804, 0.90308999, 0.95424251])

# %%
np.log(x)
# Out:
# array([0.        , 0.69314718, 1.09861229, 1.38629436, 1.60943791,
#        1.79175947, 1.94591015, 2.07944154, 2.19722458])

# %%
from math import log
nplog = np.frompyfunc(log,2,1)
nplog(10000,100)
# Out:
# 2.0

# %%
np.diff([[2,5,20,6],[2,3,4,5]])
# Out:
# array([[  3,  15, -14],
#        [  1,   1,   1]])

# %%
np.lcm(2,6)
# Out:
# 6

# %%
np.lcm.reduce([[3,45,90],[2,6,48]])
# Out:
# array([  6,  90, 720])

# %%
np.gcd.reduce([[3,45,90],[2,6,48]])
# Out:
# array([1, 3, 6])

# %%
np.cos(np.rad2deg(np.pi))
# Out:
# -0.5984600690578582

# %%
np.rad2deg(np.pi)
# Out:
# 180.0

# %%
x = np.array([0,90,180,270,360])
rad = np.deg2rad(x)
np.cos(rad)
# Out:
# array([ 1.0000000e+00,  6.1232340e-17, -1.0000000e+00, -1.8369702e-16,
#         1.0000000e+00])

# %%
np.rad2deg(np.arcsin(0.5))
# Out:
# 30.000000000000004

# %%
x = np.hypot(6,8)
x
# Out:
# 10.0
